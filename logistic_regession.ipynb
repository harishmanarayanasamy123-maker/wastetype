# %% [markdown]
# <a href="https://colab.research.google.com/github/harishmanarayanasamy123-maker/wastetype/blob/main/logistic_regession.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
import joblib

# %% [markdown]
# load dataset

# %%
data = pd.read_csv("waste_classification_dataset_500.csv")
print(data.head())
# Out:
#    Weight(g)  Moisture(%)  Hardness  Magnetic  Biodegradable WasteType
# 0         30            3         1         0              0   Plastic
# 1        190            2         8         1              0     Metal
# 2         78           78         1         0              1   Organic
# 3         79            2         7         0              0     Glass
# 4         48            3         3         0              0     Paper

# %% [markdown]
# features and target selection

# %%
x = data.drop("WasteType", axis=1)
y = data["WasteType"]
x
# Out:
#      Weight(g)  Moisture(%)  Hardness  Magnetic  Biodegradable
# 0           30            3         1         0              0
# 1          190            2         8         1              0
# 2           78           78         1         0              1
# 3           79            2         7         0              0
# 4           48            3         3         0              0
# ..         ...          ...       ...       ...            ...
# 495         21            4         3         0              0
# 496        202            1         8         1              0
# 497         86           56         1         0              1
# 498         71            6         5         0              0
# 499         58            3         4         0              0
#
# [500 rows x 5 columns]

# %% [markdown]
# encode target labels

# %%
encoder = LabelEncoder()
y = encoder.fit_transform(y)
y
# Out:
# array([4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1,
#        2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0,
#        3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4,
#        1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2,
#        0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3,
#        4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1,
#        2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0,
#        3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4,
#        1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2,
#        0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3,
#        4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1,
#        2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0,
#        3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4, 1, 2, 0, 3, 4,
# ...

# %% [markdown]
# train test split

# %%
x_train, x_test , y_train, y_test = train_test_split(x,y,test_size=0.2,random_state=42)
x_train,y_test
# Out:
# (     Weight(g)  Moisture(%)  Hardness  Magnetic  Biodegradable
#  249         37            3         3         0              0
#  433         67            6         6         0              0
#  19          54            5         5         0              0
#  322        128           69         2         0              1
#  332         72           62         2         0              1
#  ..         ...          ...       ...       ...            ...
#  106        135            3         8         1              0
#  270         14            6         1         0              0
#  348         59            6         7         0              0
#  435         36            8         2         0              0
#  102        116           80         3         0              1
#
#  [400 rows x 5 columns],
#  array([1, 0, 3, 4, 3, 3, 2, 3, 0, 4, 3, 3, 1, 3, 1, 0, 4, 4, 1, 0, 4, 1,
#         4, 1, 1, 1, 2, 1, 1, 3, 4, 1, 4, 0, 2, 0, 3, 4, 3, 0, 3, 0, 4, 4,
# ...

# %% [markdown]
# logistic regression

# %%
lr = LogisticRegression(max_iter=1000)
lr.fit(x_train, y_train)
lr_pred = lr.predict(x_test)
lr_pred
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# array([1, 0, 3, 4, 3, 3, 2, 3, 0, 3, 3, 3, 1, 3, 1, 0, 4, 4, 1, 0, 4, 1,
#        4, 1, 1, 1, 2, 1, 1, 3, 4, 1, 4, 0, 2, 0, 3, 4, 0, 0, 3, 0, 4, 4,
#        0, 2, 4, 1, 4, 2, 2, 2, 1, 4, 0, 4, 0, 0, 3, 3, 4, 2, 0, 3, 4, 3,
#        1, 1, 0, 1, 2, 1, 2, 4, 2, 3, 0, 0, 4, 4, 3, 2, 2, 2, 1, 4, 4, 3,
#        2, 0, 1, 2, 2, 0, 1, 2, 1, 4, 0, 4])

# %% [markdown]
# confusion matrix

# %%
print("Logistic Regression Accuracy")
print(accuracy_score(y_test,lr_pred))
print("\nclassification_report")
print(classification_report(y_test,lr_pred))
print("\nconfusion Matrix")
print(confusion_matrix(y_test,lr_pred))
# Out:
# Logistic Regression Accuracy
# 0.92
#
# classification_report
#               precision    recall  f1-score   support
#
#            0       0.85      0.89      0.87        19
#            1       1.00      1.00      1.00        21
#            2       1.00      1.00      1.00        18
#            3       0.83      0.75      0.79        20
#            4       0.91      0.95      0.93        22
#
#     accuracy                           0.92       100
#    macro avg       0.92      0.92      0.92       100
# weighted avg       0.92      0.92      0.92       100
#
#
# confusion Matrix
# [[17  0  0  2  0]
#  [ 0 21  0  0  0]
#  [ 0  0 18  0  0]
#  [ 3  0  0 15  2]
#  [ 0  0  0  1 21]]

# %% [markdown]
# dump file

# %%
import joblib
joblib.dump(lr,'Waste_classification.pkl')
# Out:
# ['Waste_classification.pkl']

# %%
#decision tree
dt = DecisionTreeClassifier(random_state=42)
dt.fit(x_train,y_train)
dt_pred = dt.predict(x_test)

# %%
#dt accuracy
print("Decision Tree Accuracy")
print(accuracy_score(y_test,dt_pred))
print("\nclassification report")
print(classification_report(y_test,dt_pred))
print("\nconfusion matrix")
print(confusion_matrix(y_test,dt_pred))
# Out:
# Decision Tree Accuracy
# 0.95
#
# classification report
#               precision    recall  f1-score   support
#
#            0       0.94      0.89      0.92        19
#            1       1.00      1.00      1.00        21
#            2       1.00      1.00      1.00        18
#            3       0.86      0.90      0.88        20
#            4       0.95      0.95      0.95        22
#
#     accuracy                           0.95       100
#    macro avg       0.95      0.95      0.95       100
# weighted avg       0.95      0.95      0.95       100
#
#
# confusion matrix
# [[17  0  0  2  0]
#  [ 0 21  0  0  0]
#  [ 0  0 18  0  0]
#  [ 1  0  0 18  1]
#  [ 0  0  0  1 21]]

# %%
import joblib
joblib.dump(dt,'waste_classification1.pkl')
# Out:
# ['waste_classification1.pkl']
